# %% [markdown]
# # **Project Name**    -  Amazon Prime Tv Shows And Movies EDA

# %% [markdown]
# ##### **Project Type**    - Amazon Prime Tv Shows And Movies EDA
#
# ##### **Contribution**    - Individual
# ##### Name - Hariom Upadhyay

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This project focuses on performing Exploratory Data Analysis (EDA) on the Amazon Prime Movies and TV Shows dataset to uncover meaningful insights related to content distribution, audience preferences, and platform trends. With the rapid growth of digital streaming services, data-driven decision-making has become essential for improving user experience and optimizing content strategies. The dataset includes important attributes such as title, content type (Movie or TV Show), release year, genres, IMDb ratings, TMDB scores, popularity, and cast details. Before analysis, the data was carefully preprocessed to ensure accuracy and consistency. Missing values in numerical columns were handled using median imputation to reduce the impact of outliers, while categorical fields like descriptions and IDs were filled with placeholder values. Unnecessary columns were removed, duplicates were eliminated, and both datasets were merged using a common identifier to create a clean and unified dataset.
#
# After preprocessing, various visualization techniques were applied using univariate, bivariate, and multivariate analysis to extract insights. The analysis revealed that movies significantly outnumber TV shows, indicating a stronger focus on movie-based content on the platform. A clear upward trend in content production was observed over the years, especially after 2015, reflecting the growing demand for streaming platforms. Genre analysis showed that Drama, Comedy, and Action are the most dominant categories, highlighting audience preferences. Rating distribution indicated that most content falls within a moderate score range, suggesting average audience satisfaction. Additionally, popularity analysis showed a skewed distribution, where only a few titles achieve very high popularity while most remain moderately popular.
#
# Further analysis revealed a positive correlation between IMDb and TMDB ratings, indicating consistency in content evaluation across platforms. Actor and director analysis showed that certain individuals frequently appear across multiple titles, suggesting their strong influence in the industry. Overall, this project demonstrates how EDA can transform raw data into actionable insights. These findings can help content creators and platform managers make informed decisions regarding content production, genre selection, and audience targeting. By leveraging such insights, streaming platforms can improve user engagement, enhance content quality, and maintain a competitive edge in the evolving entertainment industry.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Hariom-codes/amazon-prime-eda-project/tree/main

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# With the rapid growth of streaming platforms like Amazon Prime Video, there is a vast amount of content available in the form of movies and TV shows. However, understanding patterns in content distribution, audience preferences, and performance metrics remains a challenge.
#
# The objective of this project is to analyze the Amazon Prime Movies and TV Shows dataset to identify key trends and insights related to content type, genres, ratings, popularity, and production patterns. The analysis aims to answer important questions such as whether movies are more dominant than TV shows, which genres are most preferred, how content production has evolved over time, and how ratings vary across different platforms.
#
# By performing exploratory data analysis and visualization, the project seeks to provide meaningful insights that can help in making data-driven decisions for content strategy, audience engagement, and business growth in the streaming industry.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The primary business objective of this project is to analyze the Amazon Prime Movies and TV Shows dataset to derive actionable insights that can support strategic decision-making. The goal is to understand content trends, audience preferences, and performance metrics such as ratings and popularity.
#
# Through this analysis, the project aims to help stakeholders identify the most popular content types, genres, and production patterns. It also focuses on evaluating how factors like ratings, votes, and popularity influence audience engagement. These insights can be used to optimize content creation, improve recommendation strategies, and enhance user satisfaction.
#
# Ultimately, the objective is to enable data-driven decisions that can increase viewership, improve content quality, and strengthen the competitive position of the streaming platform in the entertainment industry.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
df1 = pd.read_csv('/content/credits.csv')
df2 = pd.read_csv('/content/titles.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df1.head()
# Out:
#    person_id       id           name      character   role
# 0      59401  ts20945     Joe Besser            Joe  ACTOR
# 1      31460  ts20945     Moe Howard            Moe  ACTOR
# 2      31461  ts20945     Larry Fine          Larry  ACTOR
# 3      21174  tm19248  Buster Keaton    Johnny Gray  ACTOR
# 4      28713  tm19248    Marion Mack  Annabelle Lee  ACTOR

# %%
df2.head()
# Out:
#         id                        title   type  \
# 0  ts20945            The Three Stooges   SHOW
# 1  tm19248                  The General  MOVIE
# 2  tm82253  The Best Years of Our Lives  MOVIE
# 3  tm83884              His Girl Friday  MOVIE
# 4  tm56584            In a Lonely Place  MOVIE
#
#                                          description  release_year  \
# 0  The Three Stooges were an American vaudeville ...          1934
# 1  During America’s Civil War, Union spies steal ...          1926
# 2  It's the hope that sustains the spirit of ever...          1946
# 3  Hildy, the journalist former wife of newspaper...          1940
# 4  An aspiring actress begins to suspect that her...          1950
#
#   age_certification  runtime  \
# 0             TV-PG       19
# 1               NaN       78
# 2               NaN      171
# 3               NaN       92
# 4               NaN       94
#
#                                               genres production_countries  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df1.shape
# Out:
# (124235, 5)

# %%
df2.shape
# Out:
# (9871, 15)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124235 entries, 0 to 124234
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   person_id  124235 non-null  int64
#  1   id         124235 non-null  object
#  2   name       124235 non-null  object
#  3   character  107948 non-null  object
#  4   role       124235 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 4.7+ MB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9871 entries, 0 to 9870
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    9871 non-null   object
#  1   title                 9871 non-null   object
#  2   type                  9871 non-null   object
#  3   description           9752 non-null   object
#  4   release_year          9871 non-null   int64
#  5   age_certification     3384 non-null   object
#  6   runtime               9871 non-null   int64
#  7   genres                9871 non-null   object
#  8   production_countries  9871 non-null   object
#  9   seasons               1357 non-null   float64
#  10  imdb_id               9204 non-null   object
#  11  imdb_score            8850 non-null   float64
#  12  imdb_votes            8840 non-null   float64
#  13  tmdb_popularity       9324 non-null   float64
#  14  tmdb_score            7789 non-null   float64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df1.duplicated().sum()
# Out:
# np.int64(56)

# %%
df2.duplicated().sum()
# Out:
# np.int64(3)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df1.isnull().sum()
# Out:
# person_id        0
# id               0
# name             0
# character    16287
# role             0
# dtype: int64

# %%
# Visualizing the missing values
sns.heatmap(df1.isnull(), cbar=False)
plt.title("Missing Values Heatmap")
plt.show()

# %%
sns.heatmap(df2.isnull(), cbar=False)
plt.title("Missing Values Heatmap")
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df1.columns
# Out:
# Index(['person_id', 'id', 'name', 'character', 'role'], dtype='object')

# %%
# Dataset Describe
df1.describe()
# Out:
#           person_id
# count  1.242350e+05
# mean   4.064737e+05
# std    5.616296e+05
# min    1.000000e+00
# 25%    3.899200e+04
# 50%    1.339490e+05
# 75%    5.712560e+05
# max    2.371153e+06

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df1.nunique()
# Out:
# person_id    80508
# id            8861
# name         79758
# character    71097
# role             2
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# 1. Clean df1

# Fill missing values in the 'character' column using the most frequent value (mode)
mode_value = df1['character'].mode()[0]
df1['character'] = df1['character'].fillna(mode_value)

# Remove duplicate rows to ensure data consistency
df1.drop_duplicates(inplace=True)


# 2. Clean df2

# Drop unnecessary columns 'seasons' and 'age_certification' if they exist
df2 = df2.drop(['seasons', 'age_certification'], axis=1, errors='ignore')

# Replace missing values in 'description' column with 'unknown'
df2['description'] = df2['description'].fillna('unknown')

# Replace missing values in 'imdb_id' column with 'unknown'
df2['imdb_id'] = df2['imdb_id'].fillna('unknown')

# List of numerical columns for handling missing values
num_cols = ['tmdb_score','tmdb_popularity','imdb_score','imdb_votes']

# Fill missing values in numerical columns using the median of each column
for col in num_cols:
    df2[col] = df2[col].fillna(df2[col].median())

# Force all object columns to string type to ensure hashability before deduplication
# This addresses potential hidden list objects in any 'object' type column
for col in df2.select_dtypes(include='object').columns:
    df2[col] = df2[col].astype(str)

# Remove duplicate rows
df2.drop_duplicates(inplace=True)

# Now, create the 'genres_list' column with actual lists
df2['genres_list'] = df2['genres'].apply(lambda x: [g.strip() for g in x.split(',') if g])


# 3. Merge (AFTER cleaning)

#consistent datasets for df1 and df2
df1['id'] = df1['id'].astype(str)
df2['id'] = df2['id'].astype(str)

# Merge df1 and df2 on the 'id' column using inner join
df = pd.merge(df2, df1, on='id', how='inner')


# 4. Final checks

# Standardize column names: convert to lowercase and replace spaces with underscores
df.columns = df.columns.str.lower().str.replace(" ", "_")

# Display dataset information (data types, non-null counts)
df.info()

# Display statistical summary of numerical columns
df.describe()

# Check remaining missing values in each column
df.isnull().sum()

#check the datatype of merged datasets
df.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124178 entries, 0 to 124177
# Data columns (total 18 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    124178 non-null  object
#  1   title                 124178 non-null  object
#  2   type                  124178 non-null  object
#  3   description           124178 non-null  object
#  4   release_year          124178 non-null  int64
#  5   runtime               124178 non-null  int64
#  6   genres                124178 non-null  object
#  7   production_countries  124178 non-null  object
#  8   imdb_id               124178 non-null  object
#  9   imdb_score            124178 non-null  float64
#  10  imdb_votes            124178 non-null  float64
#  11  tmdb_popularity       124178 non-null  float64
#  12  tmdb_score            124178 non-null  float64
#  13  genres_list           124178 non-null  object
# ...

# %%
# Outlier check of some important columns
num_cols = ['tmdb_score', 'tmdb_popularity', 'imdb_score', 'imdb_votes']

for col in num_cols:
    plt.figure(figsize=(6,3))
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col}')
    plt.show()

# %% [markdown]
# Should we remove outliers?
#
# "I analyzed outliers but did not blindly remove them, because in this dataset, high values (like high IMDb votes) can represent genuinely popular movies rather than errors."

# %%
# Apply log transformation to reduce skewness instead of removing valuable data
df['log_imdb_votes'] = np.log1p(df['imdb_votes'])

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Data Wrangling and Manipulations
#
# In this project, several data wrangling steps were performed to clean and prepare the dataset for analysis:
#
# 1. Handling Missing Values:
#  Missing values in the character column were filled using the mode (most frequent value). Numerical columns such as imdb_score, imdb_votes, tmdb_score, and tmdb_popularity were filled using the median to reduce the impact of outliers. Text-based columns like description and imdb_id were filled with the value “unknown”.
#
# 2. Dropping Irrelevant Columns:
# Columns such as seasons and age_certification were removed as they were not relevant for the analysis.
#
# 3. Removing Duplicates:
#  Duplicate records were removed from both datasets to ensure data accuracy and avoid redundancy.
#
# 4. Merging Datasets:
#  The two datasets were merged using an inner join on a common column (id) to retain only consistent and matching records.
#
# 5. Column Standardization:
#   Column names were converted to lowercase and spaces were replaced with underscores to maintain consistency and improve readability.
#
# Insights from the Analysis
#
# After performing data cleaning and analysis, the following key insights were obtained:
#
# 1. Content Distribution:
#  Movies are more dominant than TV shows on the platform.
#
# 2. Growth Trend:
#   Content production has increased significantly over the years, especially in recent years.
#
# 3. Genre Popularity:
#  Genres such as Drama, Comedy, and Action are the most common.
#
# 4. Rating Patterns:
#   Most content has moderate ratings, indicating average audience satisfaction.
#
# 5. Popularity Distribution:
#  Only a small number of titles are highly popular, while the majority have average popularity.
#
# 6. Correlation Between Platforms:
#  IMDb and TMDB scores show a positive correlation, indicating consistency in ratings across platforms.
#
# 7. Actor Participation:
# Some actors appear frequently across multiple titles, showing higher participation.
#
# 8. Production Countries:  Content production is dominated by a few countries.
#
#  Conclusion
#
# Data wrangling improved the quality and consistency of the dataset, enabling effective analysis. The insights obtained highlight key trends in content distribution, audience preferences, and rating behavior.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df2, x='type')
plt.title('Distribution of Titles (Movies vs TV Shows)')
plt.xlabel('Type')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart was chosen to visualize the distribution of categorical data (i.e., content type: Movies vs TV Shows).
#
# A countplot is the most suitable chart for:
#
# Comparing frequencies of categories
# Understanding how data is distributed across different classes
#
# It provides a clear and quick overview of which type of content is more dominant in the dataset

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# it shows that movie count is much more than shows.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ✅ Positive Impact:
#
# As Movies dominate →
# The platform is likely targeting a mass audience, as movies are generally more popular and easier to consume.
# Helps in content strategy planning, like investing more in high-performing content type.
#
# ❌ Negative Impact:
#
# As TV Shows are very less →
# It may lead to lower user retention, because TV shows usually keep users engaged for longer durations.
# Lack of variety can reduce user satisfaction and engagement

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
plt.figure(figsize=(10,5))
df2['release_year'].value_counts().sort_index().plot(kind='line')
plt.title('Number of Titles Released Per Year')
plt.xlabel('Year')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart was chosen to analyze the trend of content production over time.
#
# A line chart is ideal because:
#
# It shows changes over a continuous variable (years)
# Helps identify growth patterns, spikes, or declines
# Makes it easy to understand how content production has evolved over time

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows how the number of titles released changes year by year.
# There is usually a gradual increase in content production over time, especially in recent years.
# A sharp rise in recent years indicates the growth of streaming platforms and digital content demand.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ✅ Positive Impact:
#
# Increasing trend →
# Shows growing demand for content, which is a positive sign for the entertainment industry.
# Helps businesses decide to invest more in content production.
# Indicates opportunity for market expansion and user growth.
#
# ❌ Negative Impact:
#
# As there is a decline in certain years →
# It may indicate production issues, market saturation, or external disruptions (e.g., pandemic impact).
# Too much content growth →
# Can lead to content overload, making it harder for users to choose (decision fatigue)

# %% [markdown]
# #### Chart - 3

# %%
plt.figure(figsize=(10,5))
genres.value_counts().head(10).plot(kind='bar')
plt.title('Top 10 Genres')
plt.xlabel('Genres')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart was chosen to identify the most frequent genres in the dataset. A bar chart is ideal for comparing categorical data, as it clearly shows the top genres based on their counts, making it easy to understand which types of content are most popular or commonly produced.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that a few genres like Drama, Comedy, and Action have the highest number of titles.
# This indicates that these genres are the most commonly produced and widely available on the platform.
# There is an uneven distribution, where top genres dominate while others have significantly lower counts.
# It reflects that content production is focused on popular and high-demand genres.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ✅ Positive Impact:
#
# Helps platforms understand audience preferences, allowing them to invest more in high-demand genres.
# Improves content strategy and recommendation systems, leading to better user engagement.
# Supports targeted marketing, focusing on genres that attract more viewers.
#
# ❌ Negative Impact:
#
# Over-dependence on a few genres may lead to lack of content diversity.
# Ignoring less popular genres can result in missing niche audiences.
# Repetitive content in dominant genres may cause user fatigue over time.

# %% [markdown]
# #### Chart - 4

# %%
plt.figure(figsize=(6,5))
sns.scatterplot(data=df2, x='imdb_score', y='tmdb_score')
plt.title('IMDb vs TMDb Scores')
plt.xlabel('IMDb Score')
plt.ylabel('TMDb Score')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart was chosen to analyze the relationship between two numerical variables—IMDb score and TMDb score. A scatter plot is ideal for this purpose as it helps visualize correlations, patterns, and any inconsistencies between the two rating systems.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The scatter plot shows a positive correlation between IMDb and TMDb scores.
# Most data points lie along an upward trend, indicating that titles with higher IMDb ratings also tend to have higher TMDb ratings.
# There are a few scattered points, showing minor differences in rating systems, but overall consistency is strong.
# This suggests that both platforms generally agree on the quality of content

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ✅ Positive Impact:
#
# Consistent ratings across platforms help in building trust and credibility among users.
# Platforms can confidently use either rating system for recommendations and promotions.
# Helps in identifying high-quality content that performs well universally.
#
# ❌ Negative Impact:
#
# Minor variations in some points may indicate rating bias or differences in audience base across platforms.
# Over-reliance on ratings alone may ignore other factors like user engagement or watch time.

# %% [markdown]
# #### Chart - 5

# %%
plt.figure(figsize=(6,4))
sns.histplot(df2['imdb_score'], bins=20)
plt.title('IMDb Score Distribution')
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart was chosen to understand the distribution of IMDb scores in the dataset. A histogram is ideal for this purpose as it shows how values are spread across different ranges, helping to identify patterns such as skewness, concentration, and overall rating trends.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The histogram shows that most IMDb scores are clustered in the mid-range (around 5–7).
# Very few titles have extremely high or very low ratings, indicating a balanced distribution with limited extremes.
# This suggests that the majority of content on the platform receives average to moderately good audience ratings.
# The distribution may show slight skewness, but overall it reflects consistent content quality.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ✅ Positive Impact:
#
# Helps platforms understand that most content meets acceptable quality standards.
# Supports decision-making in promoting well-rated content to improve user satisfaction.
# Can guide producers to aim for higher-quality content to stand out.
#
# ❌ Negative Impact:
#
# Lack of highly rated content may indicate limited exceptional or standout titles.
# Too many average-rated titles can lead to reduced user excitement and engagement.
# May reflect content saturation without strong differentiation.

# %% [markdown]
# #### Chart - 6

# %%
plt.figure(figsize=(10,5))
df1['name'].value_counts().head(10).plot(kind='bar')
plt.title('Top 10 Actors by Participation')
plt.xlabel('Actor')
plt.ylabel('Number of Titles')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart was chosen to identify the top actors with the highest number of appearances in the dataset. A bar chart is ideal for comparing categorical data, as it clearly displays the frequency of each actor, making it easy to highlight the most active or frequently featured actors.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart highlights the actors with the highest number of appearances in the dataset.
# A few actors have significantly higher counts, indicating they are frequently cast across multiple titles.
# This shows a concentration of opportunities among certain popular or active actors.
# It reflects the presence of experienced or in-demand actors dominating the platform’s content.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ✅ Positive Impact:
#
# Helps identify popular actors who can attract more viewers and improve engagement.
# Useful for casting decisions and marketing strategies, leveraging well-known actors.
# Supports building brand value by associating with frequently appearing talent.
#
# ❌ Negative Impact:
#
# Over-reliance on a few actors may reduce diversity in casting.
# New or emerging actors may get fewer opportunities, limiting innovation.
# Repetition of the same actors may lead to content monotony for viewers.

# %% [markdown]
# #### Chart - 7

# %%
directors = df1[df1['role'] == 'DIRECTOR']

plt.figure(figsize=(10,5))
directors['name'].value_counts().head(10).plot(kind='bar')
plt.title('Top Directors by Number of Titles')
plt.xlabel('Director')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart was chosen to identify the most active directors based on the number of titles they have directed. A bar chart is suitable here because it effectively compares categorical data, allowing us to easily highlight and rank the top directors by their contribution.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the directors with the highest number of titles in the dataset.
# A small number of directors contribute to a large portion of the content, indicating high involvement.
# This reflects that certain directors are more active, experienced, or preferred on the platform.
# It highlights a concentration of content creation among a few key individuals.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ✅ Positive Impact:
#
# Helps identify successful and frequently contributing directors for future collaborations.
# Supports strategic partnerships with proven directors to maintain content quality.
# Useful for branding and promotions, as well-known directors can attract audiences.
#
# ❌ Negative Impact:
#
# Over-dependence on a few directors may limit creative diversity.
# New or less-known directors may face reduced opportunities, affecting innovation.
# Repetitive styles from the same directors can lead to lack of variety in content.

# %% [markdown]
# #### Chart - 8

# %%
movies = df2[df2['type'] == 'MOVIE']
shows = df2[df2['type'] == 'SHOW']

plt.figure(figsize=(10,5))

# Movie duration
sns.histplot(movies['runtime'].dropna(), bins=20, label='Movies', kde=True)

# Show duration (using runtime instead of seasons)
sns.histplot(shows['runtime'].dropna(), bins=20, label='TV Shows', kde=True)

plt.title('Content Duration Analysis')
plt.xlabel('Runtime')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart was chosen to compare the distribution of runtime between movies and TV shows. A histogram with KDE is suitable because it helps visualize how durations are spread for both categories and allows easy comparison of their patterns, such as typical length and variability.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The distribution shows that movies generally have shorter and more concentrated runtimes, often clustered around a specific range (e.g., 90–120 minutes).
# TV shows tend to have a wider spread in runtime, indicating more variability in episode or content length.
# Movies follow a more standardized duration pattern, while shows are more flexible in length.
# There is a clear distinction between how time is structured for movies vs shows.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ✅ Positive Impact:
#
# Helps platforms design content strategies based on user time preferences (short vs long content).
# Movies can target quick consumption, while shows can drive long-term engagement and retention.
# Useful for recommendation systems, suggesting content based on available viewing time.
#
# ❌ Negative Impact:
#
# If show runtimes are too inconsistent, it may affect user experience and engagement consistency.
# Over-standardization of movie duration may limit creative flexibility.
# Mismatch in user expectations (too long/short content) can reduce viewer satisfaction.

# %% [markdown]
# #### 9: pair plot

# %%
# Pair Plot visualization code
sns.pairplot(df, vars=['imdb_score','imdb_votes','tmdb_popularity','tmdb_score'], hue='type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart was chosen to explore the relationships between multiple numerical variables simultaneously and understand how they vary across different content types. A pair plot is ideal because it provides both scatter plots and distributions, helping to identify correlations, patterns, and differences between movies and TV shows in a single view.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pair plot reveals relationships between IMDb score, IMDb votes, TMDb popularity, and TMDb score.
# There is a positive relationship between IMDb score and TMDb score, indicating consistency in ratings.
# Titles with higher IMDb votes often show higher popularity, suggesting audience engagement influences visibility.
# The distribution differs slightly between Movies and TV Shows, showing variation in performance across content types.
# Some scatter plots may show weak or no correlation, indicating independent variables.

# %% [markdown]
# #####3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ✅ Positive Impact:
#
# Helps identify key factors influencing content success, such as ratings and popularity.
# Supports building better recommendation systems using correlated variables.
# Useful for targeting high-performing content based on multiple metrics.
#
# ❌ Negative Impact:
#
# Weak correlations between some variables may make prediction models less reliable.
# Over-reliance on numerical metrics may ignore qualitative aspects like storytelling or originality.
# Differences between Movies and TV Shows may require separate strategies, increasing complexity.

# %% [markdown]
# #### Chart - 10 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
numeric_df = df.select_dtypes(include=['int64', 'float64'])

sns.heatmap(numeric_df.corr(), annot=True)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart was chosen to understand the correlation between numerical variables in the dataset. A heatmap is ideal because it visually represents the strength and direction of relationships between variables, making it easy to identify strong, weak, or no correlations at a glance.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The heatmap shows the strength and direction of relationships between numerical variables.
# There is a strong positive correlation between IMDb score and TMDb score, indicating consistency in ratings.
# IMDb votes and TMDb popularity may show a moderate positive correlation, suggesting that more popular content receives higher engagement.
# Some variables show weak or no correlation, meaning they do not strongly influence each other.
# Overall, it helps identify which features are closely related and which are independent.

# %% [markdown]
# ###### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ✅ Positive Impact:
#
# Helps in feature selection for predictive models, improving accuracy.
# Identifies key performance indicators like ratings and popularity.
# Supports better decision-making in content promotion and recommendations.
#
# ❌ Negative Impact:
#
# High correlation between variables may lead to redundancy (multicollinearity) in models.
# Weak correlations may indicate limited predictive power of some features.
# Over-dependence on correlated metrics can ignore other important factors like user preferences or trends.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Business Recommendations to Achieve Objectives
#
# Based on the analysis and visualizations, the following suggestions can be made to help the client achieve business objectives:
#
# Focus on Popular Genres:
# Since genres like Drama, Comedy, and Action are the most common and preferred by audiences, the client should invest more in producing content in these genres to maximize engagement.
# Increase Content Production:
# The upward trend in content release over the years indicates growing demand. The client should continue increasing content production to stay competitive in the streaming market.
# Prioritize High-Quality Content:
# As most content has moderate ratings, there is an opportunity to improve quality. Investing in better storytelling, direction, and production can help achieve higher ratings and audience satisfaction.
# Leverage Popular Actors and Creators:
# Frequently appearing actors have a strong presence and audience appeal. Collaborating with such actors and directors can improve viewership and platform popularity.
# Target High-Performing Regions:
# Since content production is dominated by certain countries, the client should focus on these regions while also exploring new markets for expansion.
# Promote High-Potential Content:
# As only a few titles achieve very high popularity, the client should invest in marketing and promotions to boost visibility of quality content.
# Use Multi-Platform Rating Insights:
# The positive correlation between IMDb and TMDB ratings suggests consistency. The client can use these ratings to identify and promote high-performing content across platforms.
#
# By focusing on audience preferences, improving content quality, and leveraging data-driven insights, the client can enhance user engagement and achieve better business growth.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The dataset was successfully cleaned and prepared using various data wrangling techniques such as handling missing values, removing duplicates, and merging datasets. This ensured high-quality and consistent data for analysis.
#
# The exploratory data analysis revealed that movies dominate over TV shows, and content production has increased significantly over the years. Popular genres such as Drama, Comedy, and Action were identified, and most content was found to have moderate ratings. Additionally, a positive relationship was observed between IMDb and TMDB scores, indicating consistency across platforms.
#
# Overall, the analysis provides valuable insights into content trends, audience preferences, and rating patterns, which can help in making data-driven decisions in the streaming industry.
